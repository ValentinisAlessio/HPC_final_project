# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

# %% [markdown]
# # BROADCAST ALGORITHM

# %% [markdown]
# ## Binary tree algorithm

# %%
# Read in the data
bin_tree_core = pd.read_csv('../results_def/bcast_bintree_results_wu_core.csv')
bin_tree_socket = pd.read_csv('../results_def/bcast_bintree_results_wu_socket.csv')
bin_tree_node = pd.read_csv('../results_def/bcast_bintree_results_wu_node.csv')

# Merge the data
bin_tree = pd.concat([bin_tree_core, bin_tree_socket, bin_tree_node])

bin_tree.head()
bin_tree.tail()
bin_tree_socket.tail()
# Out:
#      Algorithm Allocation  Processes  MessageSize  Avg Latency(us)
# 3055  bin_tree     socket        256          128            16.94
# 3056  bin_tree     socket        256          256            13.61
# 3057  bin_tree     socket        256          512            17.22
# 3058  bin_tree     socket        256         1024            21.32
# 3059  bin_tree     socket        256         2048            31.01

# %%
# plot the results concerning the 1 MessageSize
df = bin_tree[bin_tree['MessageSize'] == 1]

sns.set_style("whitegrid")
sns.set_context("paper")
sns.set_palette("colorblind")
sns.lineplot(x='Processes', y='Avg Latency(us)', hue='Allocation', data=df, marker='o')
plt.axvline(64, color='grey', linestyle='--')
plt.axvline(128, color='grey', linestyle='--')
plt.axvline(256, color='grey', linestyle='--')
plt.xlabel('Number of Processes')
plt.ylabel('Time in microSeconds')
plt.title('Time for 1 Byte Broadcast')

# Inctrease dimensions of the plot
fig = plt.gcf()
fig.set_size_inches(6, 4)

plt.show()

# save the plot
fig.savefig('bcast_bintree_1byte.png')

# %% [markdown]
# ## Chain algorithm

# %%
chain_core = pd.read_csv('../results_def/bcast_chain_results_wu_core.csv')
chain_socket = pd.read_csv('../results_def/bcast_chain_results_wu_socket.csv')
chain_node = pd.read_csv('../results_def/bcast_chain_results_wu_node.csv')

# Merge the data
chain = pd.concat([chain_core, chain_socket, chain_node])

chain.head()
chain.tail()
chain_socket.tail()
# Out:
#      Algorithm Allocation  Processes  MessageSize  Avg Latency(us)
# 3031     chain     socket        254          128          5243.25
# 3032     chain     socket        254          256          4355.68
# 3033     chain     socket        254          512          5430.64
# 3034     chain     socket        254         1024          5117.33
# 3035     chain     socket        254         2048          4281.24

# %%
# plot the results concerning the 1 MessageSize
df = chain[chain['MessageSize'] == 1]

sns.set_style("whitegrid")
sns.set_context("paper")
sns.set_palette("colorblind")
sns.lineplot(x='Processes', y='Avg Latency(us)', hue='Allocation', data=df, marker='o')
plt.axvline(64, color='grey', linestyle='--')
plt.axvline(128, color='grey', linestyle='--')
plt.axvline(256, color='grey', linestyle='--')
plt.xlabel('Number of Processes')
plt.ylabel('Time in microSeconds')
plt.title('Latency for 1 Byte Broadcast')

# Inctrease dimensions of the plot
fig = plt.gcf()
fig.set_size_inches(6, 4)

plt.show()

# save the plot
fig.savefig('bcast_chain_1byte.png')

# %% [markdown]
# ## Linear algorithm

# %%
linear_core = pd.read_csv('../results_def/bcast_linear_results_wu_core.csv')
linear_socket = pd.read_csv('../results_def/bcast_linear_results_wu_socket.csv')
linear_node = pd.read_csv('../results_def/bcast_linear_results_wu_node.csv')

# Merge the data
linear = pd.concat([linear_core, linear_socket, linear_node])

linear.head()
linear.tail()
linear_socket.tail()
# Out:
#      Algorithm Allocation  Processes  MessageSize  Avg Latency(us)
# 3043    linear     socket        255          128          2387.59
# 3044    linear     socket        255          256          2188.28
# 3045    linear     socket        255          512          1877.55
# 3046    linear     socket        255         1024          2028.26
# 3047    linear     socket        255         2048          2201.88

# %%
# plot the results concerning the 1 MessageSize
df = linear[linear['MessageSize'] == 1]

sns.set_style("whitegrid")
sns.set_context("paper")
sns.set_palette("colorblind")
sns.lineplot(x='Processes', y='Avg Latency(us)', hue='Allocation', data=df, marker='o')
plt.axvline(64, color='grey', linestyle='--')
plt.axvline(128, color='grey', linestyle='--')
plt.axvline(256, color='grey', linestyle='--')
plt.xlabel('Number of Processes')
plt.ylabel('Time in microSeconds')
plt.title('Latency for 1 Byte Broadcast')

# Inctrease dimensions of the plot
fig = plt.gcf()
fig.set_size_inches(6, 4)

plt.show()

# save the plot
fig.savefig('bcast_linear_1byte.png')

# %% [markdown]
# ## Default algorithm

# %%
default_core = pd.read_csv('../results_def/bcast_def_results_wu_core.csv')
default_socket = pd.read_csv('../results_def/bcast_def_results_wu_socket.csv')
default_node = pd.read_csv('../results_def/bcast_def_results_wu_node.csv')

# Merge the data
default = pd.concat([default_core, default_socket, default_node])

default.head()
default.tail()
default_socket.tail()
# Out:
#      Algorithm Allocation  Processes  MessageSize  Avg Latency(us)
# 2935   default     socket        246          128            19.29
# 2936   default     socket        246          256            57.86
# 2937   default     socket        246          512            45.33
# 2938   default     socket        246         1024           103.11
# 2939   default     socket        246         2048            36.49

# %%
# plot the results concerning the 1 MessageSize
df = default[default['MessageSize'] == 1]

sns.set_style("whitegrid")
sns.set_context("paper")
sns.set_palette("colorblind")
sns.lineplot(x='Processes', y='Avg Latency(us)', hue='Allocation', data=df, marker='o')
plt.axvline(64, color='grey', linestyle='--')
plt.axvline(128, color='grey', linestyle='--')
plt.axvline(256, color='grey', linestyle='--')
plt.xlabel('Number of Processes')
plt.ylabel('Time in microSeconds')
plt.title('Latency for 1 Byte Broadcast')

# Inctrease dimensions of the plot
fig = plt.gcf()
fig.set_size_inches(6, 4)

plt.show()

# save the plot
fig.savefig('bcast_default_1byte.png')

# %% [markdown]
# ## chain vs linear

# %%
linear_core = pd.read_csv('../results_def/bcast_linear_results_wu_core.csv')
chain_core = pd.read_csv('../results_def/bcast_chain_results_wu_core.csv')

# Merge the data
data = pd.concat([linear_core, chain_core])

# %%
# plot the results concerning the 1 MessageSize
df = data[data['MessageSize'] == 1]

sns.set_style("whitegrid")
sns.set_context("paper")
sns.set_palette("colorblind")
sns.lineplot(x='Processes', y='Avg Latency(us)', hue='Algorithm', data=df, marker='o')
plt.axvline(64, color='grey', linestyle='--')
plt.axvline(128, color='grey', linestyle='--')
plt.axvline(256, color='grey', linestyle='--')
plt.xlabel('Number of Processes')
plt.ylabel('Time in microSeconds')
plt.title('Latency for 1 Byte Broadcast')

# Inctrease dimensions of the plot
fig = plt.gcf()
fig.set_size_inches(6, 4)

plt.show()

# save the plot
fig.savefig('bcast_linear_chain_1byte.png')

# %% [markdown]
# # General map by core

# %%
linear_core = pd.read_csv('../results_def/bcast_linear_results_wu_core.csv')
bin_tree_core = pd.read_csv('../results_def/bcast_bintree_results_wu_core.csv')
chain_core = pd.read_csv('../results_def/bcast_chain_results_wu_core.csv')
default_core = pd.read_csv('../results_def/bcast_def_results_wu_core.csv')

# Merge the data
data = pd.concat([linear_core, bin_tree_core, chain_core, default_core])

# plot the results concerning the 1 MessageSize
df = data[data['MessageSize'] == 1]

sns.set_style("whitegrid")
sns.set_context("paper")
sns.set_palette("colorblind")
sns.lineplot(x='Processes', y='Avg Latency(us)', hue='Algorithm', data=df, marker='o')
plt.axvline(64, color='grey', linestyle='--')
plt.axvline(128, color='grey', linestyle='--')
plt.axvline(256, color='grey', linestyle='--')
plt.xlabel('Number of Processes')
plt.ylabel('Time in microSeconds')
plt.title('Latency for 1 Byte Broadcast')

# Inctrease dimensions of the plot
fig = plt.gcf()
fig.set_size_inches(10, 6)

plt.show()

# save the plot
fig.savefig('bcast_all_1byte.png')

# %% [markdown]
# ## All by core with different sizes

# %%
data64 = data[data['MessageSize'] == 64]

sns.set_style("whitegrid")
sns.set_context("paper")
sns.set_palette("colorblind")
sns.lineplot(x='Processes', y='Avg Latency(us)', hue='Algorithm', data=data64, marker='o')
plt.axvline(64, color='grey', linestyle='--')
plt.axvline(128, color='grey', linestyle='--')
plt.axvline(256, color='grey', linestyle='--')
plt.xlabel('Number of Processes')
plt.ylabel('Time in microSeconds')
plt.title('Latency for 64 Byte Broadcast')

# Inctrease dimensions of the plot
fig = plt.gcf()
fig.set_size_inches(6, 4)

plt.show()

# save the plot
fig.savefig('bcast_all_64byte.png')

# %%
data512 = data[data['MessageSize'] == 512]

sns.set_style("whitegrid")
sns.set_context("paper")
sns.set_palette("colorblind")
sns.lineplot(x='Processes', y='Avg Latency(us)', hue='Algorithm', data=data512, marker='o')
plt.axvline(64, color='grey', linestyle='--')
plt.axvline(128, color='grey', linestyle='--')
plt.axvline(256, color='grey', linestyle='--')
plt.xlabel('Number of Processes')
plt.ylabel('Time in microSeconds')
plt.title('Latency for 512 Byte Broadcast')

# Inctrease dimensions of the plot
fig = plt.gcf()
fig.set_size_inches(6, 4)

plt.show()

# save the plot
fig.savefig('bcast_all_512byte.png')

# %%
data2048 = data[data['MessageSize'] == 2048]

sns.set_style("whitegrid")
sns.set_context("paper")
sns.set_palette("colorblind")
sns.lineplot(x='Processes', y='Avg Latency(us)', hue='Algorithm', data=data2048, marker='o')
plt.axvline(64, color='grey', linestyle='--')
plt.axvline(128, color='grey', linestyle='--')
plt.axvline(256, color='grey', linestyle='--')
plt.xlabel('Number of Processes')
plt.ylabel('Time in microSeconds')
plt.title('Latency for 2048 Byte Broadcast')

# Inctrease dimensions of the plot
fig = plt.gcf()
fig.set_size_inches(6, 4)

plt.show()

# save the plot
fig.savefig('bcast_all_2048byte.png')

# %% [markdown]
# ## Export full data for R

# %%
full_data = pd.concat([linear, bin_tree, chain, default])

full_data.to_csv('../results_def/bcast_complete.csv', index=False)
