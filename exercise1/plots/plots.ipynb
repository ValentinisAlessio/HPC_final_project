# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read in the data
df = pd.read_csv('../results/bcast_bintree_results_wu.csv')
df.head()
# Out:
#   Algorithm Allocation  Processes  MessageSize  Avg Latency(us)
# 0  bin_tree       core          2            1             0.15
# 1  bin_tree       core          2            2             0.16
# 2  bin_tree       core          2            4             0.15
# 3  bin_tree       core          2            8             0.15
# 4  bin_tree       core          2           16             0.15

# %%
# plot the results concerning the 1 MessageSize
df1 = df[df['MessageSize'] == 1]

sns.set_style("whitegrid")
sns.set_context("paper")
sns.set_palette("colorblind")
sns.lineplot(x='Processes', y='Avg Latency(us)', hue='Allocation', data=df1, marker='o')
plt.xlabel('Number of Processes')
plt.ylabel('Time in microSeconds')
plt.title('Time for 1 Byte Broadcast')

plt.show()

# %%
# save data to csv
df2 = pd.read_csv('../results/bcast_bintree_results_wu_1.csv')
df.to_csv('../results/bcast_bintree_results_wu_1.csv', index=False)
df2.to_csv('../results/bcast_bintree_results_wu.csv', index=False)
